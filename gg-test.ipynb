# %% [raw]
# !pip install requests beautifulsoup4

# %%
dimensions = ('client_id', 'topic')
dimensions
# Out:
# ('client_id', 'topic')

# %%
'client_id' in dimensions
# Out:
# True

# %%
data_types = {
	"abweichung": "DOUBLE",
	"accesslevel": "BIGINT",
	"active_alarms": "VARCHAR",
	"active_warning": "VARCHAR",
	"active_warnings": "VARCHAR",
	"actual_speed_ms": "DOUBLE",
	"actual_speed_pcs_h": "BIGINT",
	"actual_temperature_1": "DOUBLE",
	"actual_temperature_10": "DOUBLE",
	"actual_temperature_11": "DOUBLE",
	"actual_temperature_12": "DOUBLE",
	"actual_temperature_13": "DOUBLE",
	"actual_temperature_14": "DOUBLE",
	"actual_temperature_15": "DOUBLE",
	"actual_temperature_16": "DOUBLE",
	"actual_temperature_17": "DOUBLE",
	"actual_temperature_2": "DOUBLE",
	"actual_temperature_3": "DOUBLE",
	"actual_temperature_4": "DOUBLE",
	"actual_temperature_5": "DOUBLE",
	"actual_temperature_6": "DOUBLE",
	"actual_temperature_7": "DOUBLE",
	"actual_temperature_8": "DOUBLE",
	"actual_temperature_9": "DOUBLE",
	"alarm_counter": "BIGINT",
	"alarm_message": "VARCHAR",
	"alarms_counter": "BIGINT",
	"anzahlok": "BIGINT",
	"automatic_palet_counter": "BIGINT",
	"batch_bad_quality_reason": "VARCHAR",
	"batch_counter": "BIGINT",
	"batch_id": "VARCHAR",
	"batch_number": "BIGINT",
	"batch_quality_ok": "VARCHAR",
	"batch_weight_kg": "VARCHAR",
	"batchno": "BIGINT",
	"battery_ftf1_[%]": "DOUBLE",
	"battery_ftf2_[%]": "DOUBLE",
	"bbd": "VARCHAR",
	"box_counter_empty": "BIGINT",
	"box_counter_full": "BIGINT",
	"bundel_per_palet": "BIGINT",
	"bundle_counter": "BIGINT",
	"charge": "VARCHAR",
	"cnt_alarms": "BIGINT",
	"cnt_barcode_missing": "BIGINT",
	"cnt_box_empty": "BIGINT",
	"cnt_dougch_in_cold_area": "BIGINT",
	"cnt_dougch_in_teiglager": "BIGINT",
	"cnt_dougch_in_warm_area": "BIGINT",
	"cnt_dough_balls_line1": "BIGINT",
	"cnt_dough_balls_line2": "BIGINT",
	"cnt_dough_balls_line3": "BIGINT",
	"cnt_dough_balls_line4": "BIGINT",
	"cnt_dough_balls_total": "BIGINT",
	"cnt_dough_l1_left": "BIGINT",
	"cnt_dough_l1_right": "BIGINT",
	"cnt_dough_l2_left": "BIGINT",
	"cnt_dough_l2_right": "BIGINT",
	"cnt_dough_l3_left": "BIGINT",
	"cnt_dough_l3_right": "BIGINT",
	"cnt_folding_box_improperly_installed": "BIGINT",
	"cnt_folding_box_missing": "BIGINT",
	"cnt_folding_box_open_left": "BIGINT",
	"cnt_folding_box_open_right": "BIGINT",
	"cnt_kisten_c_wender": "BIGINT",
	"cnt_kisten_entstapler": "BIGINT",
	"cnt_kisten_sammelband": "BIGINT",
	"cnt_kisten_stauband": "BIGINT",
	"cnt_overload_product_insertion": "BIGINT",
	"cnt_print_missing": "BIGINT",
	"cnt_product": "BIGINT",
	"cnt_product_height_control_not_ok": "BIGINT",
	"cnt_product_in_cassette": "BIGINT",
	"cnt_product_line_1": "BIGINT",
	"cnt_product_line_2": "BIGINT",
	"cnt_product_line_3": "BIGINT",
	"cnt_product_line_4": "BIGINT",
	"cnt_product_missing": "BIGINT",
	"cnt_product_ng": "BIGINT",
	"cnt_product_ng_cont": "BIGINT",
	"cnt_product_ng_conv": "BIGINT",
	"cnt_product_ng_tu1": "BIGINT",
	"cnt_product_ng_tu2": "BIGINT",
	"cnt_product_ng_xray": "BIGINT",
	"cnt_product_not_correctly_packed": "BIGINT",
	"cnt_product_not_ok": "BIGINT",
	"cnt_product_ok": "BIGINT",
	"cnt_product_ok_soll": "BIGINT",
	"cnt_product_ok_to1": "BIGINT",
	"cnt_product_ok_to2": "BIGINT",
	"cnt_product_ok_tu1_2": "BIGINT",
	"cnt_product_pizza_left": "BIGINT",
	"cnt_product_pizza_right": "BIGINT",
	"cnt_product_row_1": "BIGINT",
	"cnt_product_row_2": "BIGINT",
	"cnt_product_row_3": "BIGINT",
	"cnt_product_row_4": "BIGINT",
	"cnt_product_sauce_general": "BIGINT",
	"cnt_product_sauce_left": "BIGINT",
	"cnt_product_sauce_right": "BIGINT",
	"cnt_product_total": "BIGINT",
	"cnt_product_total_1_2": "BIGINT",
	"cnt_product_total_3_4": "BIGINT",
	"cnt_teiglinge": "BIGINT",
	"cnt_warnings": "BIGINT",
	"counter_on_dt20_schicht_1": "BIGINT",
	"counter_on_dt20_schicht_2": "BIGINT",
	"counter_on_pp23_schicht_1": "BIGINT",
	"counter_on_pp23_schicht_2": "BIGINT",
	"counter_on_pp29_schicht_1": "BIGINT",
	"counter_on_pp29_schicht_2": "BIGINT",
	"counter_rlpal_schicht_1": "BIGINT",
	"counter_rlpal_schicht_2": "BIGINT",
	"counter_spare_schicht_1": "BIGINT",
	"counter_spare_schicht_2": "BIGINT",
	"crimperbeltspeed": "DOUBLE",
	"current_recipe": "VARCHAR",
	"customer_order_number": "BIGINT",
	"cycle_type_input_place": "VARCHAR",
	"cycle_type_outsource_place": "VARCHAR",
	"cycle_type_storage_place": "VARCHAR",
	"data": "VARCHAR",
	"db_timestamp": "VARCHAR",
	"dough_temperature_celsius": "DOUBLE",
	"effective_production_time_perc": "DOUBLE",
	"emergency_stop": "VARCHAR",
	"emergency_stop_foerdertechnik_be": "VARCHAR",
	"emergency_stop_foerdertechnik_en": "VARCHAR",
	"emergency_stop_ftf1": "VARCHAR",
	"emergency_stop_ftf2": "VARCHAR",
	"emergency_stop_main": "VARCHAR",
	"emergency_stop_rgb": "VARCHAR",
	"energy_used_wh": "BIGINT",
	"ergebnis": "VARCHAR",
	"external_id": "VARCHAR",
	"external_serial_id": "VARCHAR",
	"fässertomatenist": "DOUBLE",
	"fässertomatensoll": "DOUBLE",
	"gesamt": "DOUBLE",
	"giveaway": "DOUBLE",
	"hefeist": "DOUBLE",
	"hefesoll": "DOUBLE",
	"hopperempty": "BIGINT",
	"incoming_material_shortage": "VARCHAR",
	"incoming_material_shortage_type": "VARCHAR",
	"kneader_operating_mode": "VARCHAR",
	"knoblauchgranulatist": "DOUBLE",
	"knoblauchgranulatsoll": "DOUBLE",
	"lifebit": "BIGINT",
	"line_id": "VARCHAR",
	"liquidrecipename": "VARCHAR",
	"machine_data1": "VARCHAR",
	"machine_data13": "VARCHAR",
	"machine_data15": "VARCHAR",
	"machine_data16": "VARCHAR",
	"machine_data2": "VARCHAR",
	"machine_data3": "VARCHAR",
	"machine_data4": "VARCHAR",
	"machine_data5": "VARCHAR",
	"machine_data6": "VARCHAR",
	"machine_data7": "VARCHAR",
	"machine_speed": "DOUBLE",
	"machine_status": "VARCHAR",
	"machine_status_foerdertechnik": "VARCHAR",
	"machine_status_ftf1": "VARCHAR",
	"machine_status_ftf2": "VARCHAR",
	"machine_status_main": "VARCHAR",
	"machine_status_rgb_1": "VARCHAR",
	"machine_status_rgb_2": "VARCHAR",
	"machineidle": "BIGINT",
	"machineinproduction": "BIGINT",
	"mainspeed": "DOUBLE",
	"manual_palet_counter": "BIGINT",
	"materialnumber": "VARCHAR",
	"max": "DOUBLE",
	"min": "DOUBLE",
	"mittel": "DOUBLE",
	"mqtt_cnt_kisten_c_wende": "BIGINT",
	"mqtt_cnt_kisten_c_wender": "BIGINT",
	"nenncharge": "DOUBLE",
	"nennfuellmenge": "VARCHAR",
	"ölist": "DOUBLE",
	"ölsoll": "DOUBLE",
	"operating_mode": "VARCHAR",
	"operating_mode_foerdertechnik": "VARCHAR",
	"operating_mode_ftf1": "VARCHAR",
	"operating_mode_ftf2": "VARCHAR",
	"operating_mode_main": "VARCHAR",
	"operating_mode_rgb_1": "VARCHAR",
	"operating_mode_rgb_2": "VARCHAR",
	"operationmode": "BIGINT",
	"oreganoist": "DOUBLE",
	"oreganosoll": "DOUBLE",
	"outlet_occupied": "VARCHAR",
	"outlet_occupied_reason": "VARCHAR",
	"outlet_occupied_type": "VARCHAR",
	"oven_cycles": "VARCHAR",
	"pause_time": "BIGINT",
	"pfefferist": "DOUBLE",
	"pfeffersoll": "DOUBLE",
	"place_counter_empty": "BIGINT",
	"product_change": "VARCHAR",
	"product_counter": "BIGINT",
	"product_id": "VARCHAR",
	"product_name": "VARCHAR",
	"produkt_counter": "BIGINT",
	"produktname": "VARCHAR",
	"produktnummer": "VARCHAR",
	"program_number": "BIGINT",
	"quality_data1": "BIGINT",
	"quality_data2": "BIGINT",
	"quality_data3": "BIGINT",
	"quality_data4": "BIGINT",
	"quality_data5": "VARCHAR",
	"quantity": "DOUBLE",
	"receipt_change": "VARCHAR",
	"receipt_name": "VARCHAR",
	"recept_name": "VARCHAR",
	"recipe_number": "BIGINT",
	"recipeno": "BIGINT",
	"recipewatertemperature": "DOUBLE",
	"safety_doors_opened": "VARCHAR",
	"salzist": "DOUBLE",
	"salzsoll": "DOUBLE",
	"set_speed_pcs_h": "BIGINT",
	"setpoint_temperature_1": "DOUBLE",
	"setpoint_temperature_10": "DOUBLE",
	"setpoint_temperature_11": "DOUBLE",
	"setpoint_temperature_12": "DOUBLE",
	"setpoint_temperature_13": "DOUBLE",
	"setpoint_temperature_14": "DOUBLE",
	"setpoint_temperature_15": "DOUBLE",
	"setpoint_temperature_16": "DOUBLE",
	"setpoint_temperature_17": "DOUBLE",
	"setpoint_temperature_2": "DOUBLE",
	"setpoint_temperature_3": "DOUBLE",
	"setpoint_temperature_4": "DOUBLE",
	"setpoint_temperature_5": "DOUBLE",
	"setpoint_temperature_6": "DOUBLE",
	"setpoint_temperature_7": "DOUBLE",
	"setpoint_temperature_8": "DOUBLE",
	"setpoint_temperature_9": "DOUBLE",
	"site_id": "VARCHAR",
	"soft_start": "BIGINT",
	"speed_of_blade_motor": "DOUBLE",
	"speedlimit": "DOUBLE",
	"start": "VARCHAR",
	"stopp": "VARCHAR",
	"storagename": "VARCHAR",
	"storagequantity": "DOUBLE",
	"time_stamp": "VARCHAR",
	"time_statistic_start": "VARCHAR",
	"tipper_operating_mode": "VARCHAR",
	"to1anzahl": "BIGINT",
	"to1gewicht": "DOUBLE",
	"to2anzahl": "BIGINT",
	"to2gewicht": "DOUBLE",
	"transport_operating_mode": "VARCHAR",
	"tu1anzahl": "BIGINT",
	"tu1ausgeschleust": "BIGINT",
	"tu1gewicht": "DOUBLE",
	"tu1nicht": "BIGINT",
	"tu1nichtprozent": "DOUBLE",
	"tu2anzahl": "BIGINT",
	"tu2gewicht": "DOUBLE",
	"unit_of_measure": "VARCHAR",
	"unit_per_bundel": "BIGINT",
	"warning_message": "VARCHAR",
	"warnings_counter": "BIGINT",
	"wasserist": "DOUBLE",
	"wassersoll": "DOUBLE",
	"weight_mean_value": "DOUBLE",
	"weizenmehlist": "DOUBLE",
	"weizenmehlsoll": "DOUBLE",
	"zzz": "BIGINT"
}

# %%
data_types
# Out:
# {'abweichung': 'DOUBLE',
#  'accesslevel': 'BIGINT',
#  'active_alarms': 'VARCHAR',
#  'active_warning': 'VARCHAR',
#  'active_warnings': 'VARCHAR',
#  'actual_speed_ms': 'DOUBLE',
#  'actual_speed_pcs_h': 'BIGINT',
#  'actual_temperature_1': 'DOUBLE',
#  'actual_temperature_10': 'DOUBLE',
#  'actual_temperature_11': 'DOUBLE',
#  'actual_temperature_12': 'DOUBLE',
#  'actual_temperature_13': 'DOUBLE',
#  'actual_temperature_14': 'DOUBLE',
#  'actual_temperature_15': 'DOUBLE',
#  'actual_temperature_16': 'DOUBLE',
#  'actual_temperature_17': 'DOUBLE',
#  'actual_temperature_2': 'DOUBLE',
#  'actual_temperature_3': 'DOUBLE',
#  'actual_temperature_4': 'DOUBLE',
#  'actual_temperature_5': 'DOUBLE',
#  'actual_temperature_6': 'DOUBLE',
#  'actual_temperature_7': 'DOUBLE',
#  'actual_temperature_8': 'DOUBLE',
#  'actual_temperature_9': 'DOUBLE',
#  'alarm_counter': 'BIGINT',
#  'alarm_message': 'VARCHAR',
#  'alarms_counter': 'BIGINT',
#  'anzahlok': 'BIGINT',
# ...

# %%
data_types.get('outlet_occupied_reason', None)
